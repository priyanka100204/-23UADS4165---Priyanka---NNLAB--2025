# %%
import tensorflow.compat.v1 as tf
import numpy as np
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
import time
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Disable TensorFlow 2 behavior
tf.disable_v2_behavior()

# Load MNIST dataset
mnist = tfds.load('mnist', split=['train', 'test'], as_supervised=True)
train_data, test_data = mnist

# Network Parameters
input_size = 784  # 28x28 images
output_size = 10
learning_rate = 0.01
epochs = 50
batch_size = 10

# Hyperparameters to tune
activation_functions = {'relu': tf.nn.relu, 'sigmoid': tf.nn.sigmoid, 'tanh': tf.nn.tanh}
hidden_layer_sizes = [256, 128, 64]

# Function to preprocess images
def preprocess(images, labels):
    images = tf.cast(images, tf.float32) / 255.0  # Normalize
    images = tf.reshape(images, [784])  # Flatten
    labels = tf.one_hot(labels, depth=10)  # One-hot encode labels
    return images, labels

# Apply preprocessing and batch the data
train_data = train_data.map(preprocess).batch(batch_size)
test_data = test_data.map(preprocess).batch(batch_size)

# Placeholder for results
results = []

# Iterate over hyperparameters
for activation_name, activation_func in activation_functions.items():
    for hidden_layer_size in hidden_layer_sizes:
        print(f"Training with Activation: {activation_name}, Hidden Layer Size: {hidden_layer_size}")

        # Define placeholders
        X = tf.placeholder(tf.float32, [None, input_size])
        Y = tf.placeholder(tf.float32, [None, output_size])

        # Initialize weights and biases
        weights = {
            'h1': tf.Variable(tf.random_normal([input_size, hidden_layer_size])),
            'out': tf.Variable(tf.random_normal([hidden_layer_size, output_size]))
        }
        biases = {
            'b1': tf.Variable(tf.random_normal([hidden_layer_size])),
            'out': tf.Variable(tf.random_normal([output_size]))
        }

        # Define the neural network
        def neural_network(x):
            layer1 = activation_func(tf.add(tf.matmul(x, weights['h1']), biases['b1']))
            output_layer = tf.add(tf.matmul(layer1, weights['out']), biases['out'])
            return output_layer

        logits = neural_network(X)
        predictions = tf.nn.softmax(logits)

        # Define loss and optimizer
        loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=logits, labels=Y))
        optimizer = tf.train.AdamOptimizer(learning_rate).minimize(loss)

        # Define accuracy metric
        correct_pred = tf.equal(tf.argmax(predictions, 1), tf.argmax(Y, 1))
        accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

        # Start session
        with tf.Session() as sess:
            sess.run(tf.global_variables_initializer())
            train_losses, train_accuracies = [], []
            start_time = time.time()

            for epoch in range(epochs):
                avg_loss = 0
                total_batches = 0
                iterator = tf.compat.v1.data.make_one_shot_iterator(train_data)
                next_batch = iterator.get_next()

                while True:
                    try:
                        batch_x, batch_y = sess.run(next_batch)
                        _, c, acc = sess.run([optimizer, loss, accuracy], feed_dict={X: batch_x, Y: batch_y})
                        avg_loss += c
                        total_batches += 1
                    except tf.errors.OutOfRangeError:
                        break

                avg_loss /= total_batches
                train_losses.append(avg_loss)
                train_accuracies.append(acc)
                print(f"Epoch {epoch+1}, Loss: {avg_loss:.4f}, Accuracy: {acc:.4f}")

            end_time = time.time()
            execution_time = end_time - start_time

            # Evaluate model
            test_acc = []
            y_true, y_pred = [], []
            iterator = tf.compat.v1.data.make_one_shot_iterator(test_data)
            next_batch = iterator.get_next()

            while True:
                try:
                    batch_x, batch_y = sess.run(next_batch)
                    acc, preds = sess.run([accuracy, predictions], feed_dict={X: batch_x, Y: batch_y})
                    test_acc.append(acc)
                    y_true.extend(np.argmax(batch_y, axis=1))
                    y_pred.extend(np.argmax(preds, axis=1))
                except tf.errors.OutOfRangeError:
                    break

            final_test_accuracy = np.mean(test_acc)
            results.append((activation_name, hidden_layer_size, final_test_accuracy, execution_time))

            print(f"Final Test Accuracy: {final_test_accuracy:.4f}")
            print(f"Execution Time: {execution_time:.2f} seconds\n")

            # Plot loss and accuracy curves
            plt.figure(figsize=(12, 5))
            plt.subplot(1, 2, 1)
            plt.plot(range(epochs), train_losses, label='Loss')
            plt.xlabel('Epochs')
            plt.ylabel('Loss')
            plt.title(f'Loss Curve - {activation_name}, {hidden_layer_size}')
            plt.legend()

            plt.subplot(1, 2, 2)
            plt.plot(range(epochs), train_accuracies, label='Accuracy', color='green')
            plt.xlabel('Epochs')
            plt.ylabel('Accuracy')
            plt.title(f'Accuracy Curve - {activation_name}, {hidden_layer_size}')
            plt.legend()
            plt.show()

            # Confusion matrix
            cm = confusion_matrix(y_true, y_pred)
            plt.figure(figsize=(8, 6))
            sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=range(10), yticklabels=range(10))
            plt.xlabel('Predicted')
            plt.ylabel('Actual')
            plt.title(f'Confusion Matrix - {activation_name}, {hidden_layer_size}')
            plt.show()

# Print summary of results
print("\nHyperparameter Tuning Results:")
for activation, hl_size, acc, time_taken in results:
    print(f"Activation: {activation}, Hidden Layer: {hl_size}, Test Accuracy: {acc:.4f}, Time: {time_taken:.2f}s")
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.11/dist-packages/tensorflow/python/compat/v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:absl:Variant folder /root/tensorflow_datasets/mnist/3.0.1 has no dataset_info.json
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to /root/tensorflow_datasets/mnist/3.0.1...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/mnist/incomplete.TH1VWN_3.0.1/mnist-train.tfrecord*...:   0%|          | 0…
# Generating test examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/mnist/incomplete.TH1VWN_3.0.1/mnist-test.tfrecord*...:   0%|          | 0/…
# Dataset mnist downloaded and prepared to /root/tensorflow_datasets/mnist/3.0.1. Subsequent calls will reuse this data.
# Training with Activation: relu, Hidden Layer Size: 256
# Epoch 1, Loss: 2.5876, Accuracy: 0.9000
# Epoch 2, Loss: 0.3735, Accuracy: 1.0000
# Epoch 3, Loss: 0.2949, Accuracy: 1.0000
# Epoch 4, Loss: 0.2603, Accuracy: 1.0000
# Epoch 5, Loss: 0.2442, Accuracy: 1.0000
# Epoch 6, Loss: 0.2288, Accuracy: 1.0000
# Epoch 7, Loss: 0.2154, Accuracy: 1.0000
# Epoch 8, Loss: 0.2033, Accuracy: 1.0000
# Epoch 9, Loss: 0.2114, Accuracy: 1.0000
# Epoch 10, Loss: 0.2037, Accuracy: 1.0000
# Epoch 11, Loss: 0.2052, Accuracy: 1.0000
# Epoch 12, Loss: 0.1861, Accuracy: 1.0000
# Epoch 13, Loss: 0.1868, Accuracy: 1.0000
# Epoch 14, Loss: 0.1806, Accuracy: 1.0000
# Epoch 15, Loss: 0.1954, Accuracy: 1.0000
# Epoch 16, Loss: 0.1743, Accuracy: 1.0000
# Epoch 17, Loss: 0.1788, Accuracy: 1.0000
# Epoch 18, Loss: 0.1612, Accuracy: 1.0000
# Epoch 19, Loss: 0.1691, Accuracy: 1.0000
# Epoch 20, Loss: 0.1716, Accuracy: 1.0000
# Epoch 21, Loss: 0.1642, Accuracy: 1.0000
# Epoch 22, Loss: 0.1603, Accuracy: 1.0000
# Epoch 23, Loss: 0.1547, Accuracy: 1.0000
# Epoch 24, Loss: 0.1545, Accuracy: 1.0000
# Epoch 25, Loss: 0.1622, Accuracy: 1.0000
# Epoch 26, Loss: 0.1510, Accuracy: 1.0000
# Epoch 27, Loss: 0.1453, Accuracy: 1.0000
# Epoch 28, Loss: 0.1554, Accuracy: 1.0000
# Epoch 29, Loss: 0.1526, Accuracy: 1.0000
# Epoch 30, Loss: 0.1371, Accuracy: 0.9000
# Epoch 31, Loss: 0.1353, Accuracy: 1.0000
# Epoch 32, Loss: 0.1462, Accuracy: 1.0000
# Epoch 33, Loss: 0.1393, Accuracy: 1.0000
# Epoch 34, Loss: 0.1350, Accuracy: 1.0000
# Epoch 35, Loss: 0.1344, Accuracy: 1.0000
# Epoch 36, Loss: 0.1347, Accuracy: 1.0000
# Epoch 37, Loss: 0.1340, Accuracy: 1.0000
# Epoch 38, Loss: 0.1138, Accuracy: 1.0000
# Epoch 39, Loss: 0.1305, Accuracy: 1.0000
# Epoch 40, Loss: 0.1225, Accuracy: 1.0000
# Epoch 41, Loss: 0.1231, Accuracy: 1.0000
# Epoch 42, Loss: 0.1143, Accuracy: 1.0000
# Epoch 43, Loss: 0.1087, Accuracy: 1.0000
# Epoch 44, Loss: 0.1174, Accuracy: 1.0000
# Epoch 45, Loss: 0.1216, Accuracy: 1.0000
# Epoch 46, Loss: 0.1127, Accuracy: 1.0000
# Epoch 47, Loss: 0.1217, Accuracy: 1.0000
# Epoch 48, Loss: 0.1197, Accuracy: 1.0000
# Epoch 49, Loss: 0.1163, Accuracy: 1.0000
# Epoch 50, Loss: 0.1069, Accuracy: 1.0000
# Final Test Accuracy: 0.9619
# Execution Time: 865.33 seconds
# Training with Activation: relu, Hidden Layer Size: 128
# Epoch 1, Loss: 1.6239, Accuracy: 1.0000
# Epoch 2, Loss: 0.3190, Accuracy: 0.9000
# Epoch 3, Loss: 0.2548, Accuracy: 0.9000
# Epoch 4, Loss: 0.2334, Accuracy: 1.0000
# Epoch 5, Loss: 0.2224, Accuracy: 1.0000
# Epoch 6, Loss: 0.2064, Accuracy: 1.0000
# Epoch 7, Loss: 0.2071, Accuracy: 1.0000
# Epoch 8, Loss: 0.1968, Accuracy: 1.0000
# Epoch 9, Loss: 0.1832, Accuracy: 1.0000
# Epoch 10, Loss: 0.1785, Accuracy: 0.9000
# Epoch 11, Loss: 0.1738, Accuracy: 1.0000
# Epoch 12, Loss: 0.1811, Accuracy: 1.0000
# Epoch 13, Loss: 0.1639, Accuracy: 1.0000
# Epoch 14, Loss: 0.1676, Accuracy: 1.0000
# Epoch 15, Loss: 0.1628, Accuracy: 0.9000
# Epoch 16, Loss: 0.1682, Accuracy: 1.0000
# Epoch 17, Loss: 0.1571, Accuracy: 1.0000
# Epoch 18, Loss: 0.1592, Accuracy: 1.0000
# Epoch 19, Loss: 0.1561, Accuracy: 1.0000
# Epoch 20, Loss: 0.1541, Accuracy: 1.0000
# Epoch 21, Loss: 0.1627, Accuracy: 1.0000
# Epoch 22, Loss: 0.1414, Accuracy: 1.0000
# Epoch 23, Loss: 0.1539, Accuracy: 1.0000
# Epoch 24, Loss: 0.1542, Accuracy: 1.0000
# Epoch 25, Loss: 0.1479, Accuracy: 1.0000
# Epoch 26, Loss: 0.1398, Accuracy: 1.0000
# Epoch 27, Loss: 0.1412, Accuracy: 1.0000
# Epoch 28, Loss: 0.1362, Accuracy: 1.0000
# Epoch 29, Loss: 0.1456, Accuracy: 1.0000
# Epoch 30, Loss: 0.1343, Accuracy: 1.0000
# Epoch 31, Loss: 0.1450, Accuracy: 1.0000
# Epoch 32, Loss: 0.1427, Accuracy: 1.0000
# Epoch 33, Loss: 0.1298, Accuracy: 1.0000
# Epoch 34, Loss: 0.1343, Accuracy: 1.0000
# Epoch 35, Loss: 0.1399, Accuracy: 1.0000
# Epoch 36, Loss: 0.1264, Accuracy: 1.0000
# Epoch 37, Loss: 0.1267, Accuracy: 1.0000
# Epoch 38, Loss: 0.1416, Accuracy: 1.0000
# Epoch 39, Loss: 0.1224, Accuracy: 1.0000
# Epoch 40, Loss: 0.1298, Accuracy: 1.0000
# Epoch 41, Loss: 0.1337, Accuracy: 1.0000
# Epoch 42, Loss: 0.1324, Accuracy: 1.0000
# Epoch 43, Loss: 0.1258, Accuracy: 1.0000
# Epoch 44, Loss: 0.1255, Accuracy: 1.0000
# Epoch 45, Loss: 0.1250, Accuracy: 1.0000
# Epoch 46, Loss: 0.1301, Accuracy: 1.0000
# Epoch 47, Loss: 0.1400, Accuracy: 1.0000
# Epoch 48, Loss: 0.1265, Accuracy: 1.0000
# Epoch 49, Loss: 0.1257, Accuracy: 1.0000
# Epoch 50, Loss: 0.1183, Accuracy: 1.0000
# Final Test Accuracy: 0.9590
# Execution Time: 742.99 seconds
# Training with Activation: relu, Hidden Layer Size: 64
# Epoch 1, Loss: 1.3026, Accuracy: 0.9000
# Epoch 2, Loss: 0.2904, Accuracy: 1.0000
# Epoch 3, Loss: 0.2543, Accuracy: 1.0000
# Epoch 4, Loss: 0.2278, Accuracy: 1.0000
# Epoch 5, Loss: 0.2213, Accuracy: 1.0000
# Epoch 6, Loss: 0.2089, Accuracy: 1.0000
# Epoch 7, Loss: 0.1999, Accuracy: 1.0000
# Epoch 8, Loss: 0.1901, Accuracy: 1.0000
# Epoch 9, Loss: 0.1910, Accuracy: 0.9000
# Epoch 10, Loss: 0.1975, Accuracy: 1.0000
# Epoch 11, Loss: 0.1782, Accuracy: 1.0000
# Epoch 12, Loss: 0.1830, Accuracy: 1.0000
# Epoch 13, Loss: 0.1780, Accuracy: 1.0000
# Epoch 14, Loss: 0.1769, Accuracy: 1.0000
# Epoch 15, Loss: 0.1780, Accuracy: 1.0000
# Epoch 16, Loss: 0.1750, Accuracy: 1.0000
# Epoch 17, Loss: 0.1644, Accuracy: 1.0000
# Epoch 18, Loss: 0.1575, Accuracy: 1.0000
# Epoch 19, Loss: 0.1669, Accuracy: 1.0000
# Epoch 20, Loss: 0.1569, Accuracy: 1.0000
# Epoch 21, Loss: 0.1593, Accuracy: 1.0000
# Epoch 22, Loss: 0.1652, Accuracy: 1.0000
# Epoch 23, Loss: 0.1577, Accuracy: 1.0000
# Epoch 24, Loss: 0.1526, Accuracy: 1.0000
# Epoch 25, Loss: 0.1610, Accuracy: 1.0000
# Epoch 26, Loss: 0.1629, Accuracy: 1.0000
# Epoch 27, Loss: 0.1467, Accuracy: 1.0000
# Epoch 28, Loss: 0.1491, Accuracy: 1.0000
# Epoch 29, Loss: 0.1499, Accuracy: 1.0000
# Epoch 30, Loss: 0.1461, Accuracy: 1.0000
# Epoch 31, Loss: 0.1503, Accuracy: 1.0000
# Epoch 32, Loss: 0.1485, Accuracy: 1.0000
# Epoch 33, Loss: 0.1491, Accuracy: 1.0000
# Epoch 34, Loss: 0.1495, Accuracy: 1.0000
# Epoch 35, Loss: 0.1500, Accuracy: 1.0000
# Epoch 36, Loss: 0.1365, Accuracy: 1.0000
# Epoch 37, Loss: 0.1462, Accuracy: 1.0000
# Epoch 38, Loss: 0.1396, Accuracy: 1.0000
# Epoch 39, Loss: 0.1487, Accuracy: 1.0000
# Epoch 40, Loss: 0.1471, Accuracy: 1.0000
# Epoch 41, Loss: 0.1370, Accuracy: 1.0000
# Epoch 42, Loss: 0.1411, Accuracy: 1.0000
# Epoch 43, Loss: 0.1429, Accuracy: 0.9000
# Epoch 44, Loss: 0.1421, Accuracy: 1.0000
# Epoch 45, Loss: 0.1442, Accuracy: 1.0000
# Epoch 46, Loss: 0.1464, Accuracy: 1.0000
# Epoch 47, Loss: 0.1386, Accuracy: 1.0000
# Epoch 48, Loss: 0.1456, Accuracy: 1.0000
# Epoch 49, Loss: 0.1473, Accuracy: 1.0000
# Epoch 50, Loss: 0.1451, Accuracy: 1.0000
# Final Test Accuracy: 0.9472
# Execution Time: 692.20 seconds
# Training with Activation: sigmoid, Hidden Layer Size: 256
# Epoch 1, Loss: 0.5291, Accuracy: 0.9000
# Epoch 2, Loss: 0.2863, Accuracy: 1.0000
# Epoch 3, Loss: 0.2511, Accuracy: 0.9000
# Epoch 4, Loss: 0.2280, Accuracy: 1.0000
# Epoch 5, Loss: 0.2205, Accuracy: 1.0000
# Epoch 6, Loss: 0.1949, Accuracy: 1.0000
# Epoch 7, Loss: 0.1898, Accuracy: 1.0000
# Epoch 8, Loss: 0.1812, Accuracy: 1.0000
# Epoch 9, Loss: 0.1689, Accuracy: 1.0000
# Epoch 10, Loss: 0.1694, Accuracy: 1.0000
# Epoch 11, Loss: 0.1567, Accuracy: 1.0000
# Epoch 12, Loss: 0.1547, Accuracy: 1.0000
# Epoch 13, Loss: 0.1469, Accuracy: 1.0000
# Epoch 14, Loss: 0.1402, Accuracy: 1.0000
# Epoch 15, Loss: 0.1378, Accuracy: 0.9000
# Epoch 16, Loss: 0.1392, Accuracy: 1.0000
# Epoch 17, Loss: 0.1292, Accuracy: 1.0000
# Epoch 18, Loss: 0.1351, Accuracy: 1.0000
# Epoch 19, Loss: 0.1336, Accuracy: 1.0000
# Epoch 20, Loss: 0.1206, Accuracy: 1.0000
# Epoch 21, Loss: 0.1086, Accuracy: 1.0000
# Epoch 22, Loss: 0.1131, Accuracy: 1.0000
# Epoch 23, Loss: 0.1164, Accuracy: 1.0000
# Epoch 24, Loss: 0.1132, Accuracy: 1.0000
# Epoch 25, Loss: 0.1101, Accuracy: 1.0000
# Epoch 26, Loss: 0.1096, Accuracy: 1.0000
# Epoch 27, Loss: 0.0979, Accuracy: 1.0000
# Epoch 28, Loss: 0.0985, Accuracy: 1.0000
# Epoch 29, Loss: 0.0958, Accuracy: 1.0000
# Epoch 30, Loss: 0.0913, Accuracy: 1.0000
# Epoch 31, Loss: 0.0882, Accuracy: 1.0000
# Epoch 32, Loss: 0.0795, Accuracy: 1.0000
# Epoch 33, Loss: 0.0882, Accuracy: 1.0000
# Epoch 34, Loss: 0.0855, Accuracy: 1.0000
# Epoch 35, Loss: 0.0833, Accuracy: 1.0000
# Epoch 36, Loss: 0.0870, Accuracy: 1.0000
# Epoch 37, Loss: 0.0744, Accuracy: 1.0000
# Epoch 38, Loss: 0.0891, Accuracy: 1.0000
# Epoch 39, Loss: 0.0801, Accuracy: 1.0000
# Epoch 40, Loss: 0.0784, Accuracy: 1.0000
# Epoch 41, Loss: 0.0759, Accuracy: 1.0000
# Epoch 42, Loss: 0.0733, Accuracy: 1.0000
# Epoch 43, Loss: 0.0726, Accuracy: 1.0000
# Epoch 44, Loss: 0.0662, Accuracy: 1.0000
# Epoch 45, Loss: 0.0774, Accuracy: 1.0000
# Epoch 46, Loss: 0.0693, Accuracy: 1.0000
# Epoch 47, Loss: 0.0829, Accuracy: 1.0000
# Epoch 48, Loss: 0.0709, Accuracy: 1.0000
# Epoch 49, Loss: 0.0653, Accuracy: 1.0000
# Epoch 50, Loss: 0.0612, Accuracy: 1.0000
# Final Test Accuracy: 0.9685
# Execution Time: 902.55 seconds
# Training with Activation: sigmoid, Hidden Layer Size: 128
# Epoch 1, Loss: 0.4049, Accuracy: 1.0000
# Epoch 2, Loss: 0.2205, Accuracy: 1.0000
# Epoch 3, Loss: 0.1793, Accuracy: 1.0000
# Epoch 4, Loss: 0.1565, Accuracy: 1.0000
# Epoch 5, Loss: 0.1508, Accuracy: 1.0000
# Epoch 6, Loss: 0.1401, Accuracy: 1.0000
# Epoch 7, Loss: 0.1303, Accuracy: 1.0000
# Epoch 8, Loss: 0.1224, Accuracy: 1.0000
# Epoch 9, Loss: 0.1226, Accuracy: 1.0000
# Epoch 10, Loss: 0.1194, Accuracy: 1.0000
# Epoch 11, Loss: 0.1151, Accuracy: 1.0000
# Epoch 12, Loss: 0.1079, Accuracy: 1.0000
# Epoch 13, Loss: 0.1075, Accuracy: 1.0000
# Epoch 14, Loss: 0.1057, Accuracy: 1.0000
# Epoch 15, Loss: 0.0976, Accuracy: 1.0000
# Epoch 16, Loss: 0.1009, Accuracy: 1.0000
# Epoch 17, Loss: 0.0996, Accuracy: 1.0000
# Epoch 18, Loss: 0.0927, Accuracy: 1.0000
# Epoch 19, Loss: 0.0946, Accuracy: 1.0000
# Epoch 20, Loss: 0.0832, Accuracy: 1.0000
# Epoch 21, Loss: 0.0836, Accuracy: 1.0000
# Epoch 22, Loss: 0.0824, Accuracy: 1.0000
# Epoch 23, Loss: 0.0796, Accuracy: 1.0000
# Epoch 24, Loss: 0.0791, Accuracy: 1.0000
# Epoch 25, Loss: 0.0725, Accuracy: 1.0000
# Epoch 26, Loss: 0.0723, Accuracy: 1.0000
# Epoch 27, Loss: 0.0744, Accuracy: 1.0000
# Epoch 28, Loss: 0.0681, Accuracy: 1.0000
# Epoch 29, Loss: 0.0716, Accuracy: 1.0000
# Epoch 30, Loss: 0.0771, Accuracy: 1.0000
# Epoch 31, Loss: 0.0697, Accuracy: 1.0000
# Epoch 32, Loss: 0.0710, Accuracy: 1.0000
# Epoch 33, Loss: 0.0688, Accuracy: 1.0000
# Epoch 34, Loss: 0.0590, Accuracy: 1.0000
# Epoch 35, Loss: 0.0658, Accuracy: 1.0000
# Epoch 36, Loss: 0.0655, Accuracy: 1.0000
# Epoch 37, Loss: 0.0663, Accuracy: 1.0000
# Epoch 38, Loss: 0.0657, Accuracy: 1.0000
# Epoch 39, Loss: 0.0659, Accuracy: 1.0000
# Epoch 40, Loss: 0.0641, Accuracy: 1.0000
# Epoch 41, Loss: 0.0588, Accuracy: 1.0000
# Epoch 42, Loss: 0.0605, Accuracy: 1.0000
# Epoch 43, Loss: 0.0593, Accuracy: 1.0000
# Epoch 44, Loss: 0.0634, Accuracy: 1.0000
# Epoch 45, Loss: 0.0627, Accuracy: 1.0000
# Epoch 46, Loss: 0.0656, Accuracy: 1.0000
# Epoch 47, Loss: 0.0544, Accuracy: 1.0000
# Epoch 48, Loss: 0.0573, Accuracy: 1.0000
# Epoch 49, Loss: 0.0518, Accuracy: 1.0000
# Epoch 50, Loss: 0.0518, Accuracy: 1.0000
# Final Test Accuracy: 0.9700
# Execution Time: 740.81 seconds
# Training with Activation: sigmoid, Hidden Layer Size: 64
# Epoch 1, Loss: 0.3759, Accuracy: 1.0000
# Epoch 2, Loss: 0.2147, Accuracy: 1.0000
# Epoch 3, Loss: 0.1842, Accuracy: 1.0000
# Epoch 4, Loss: 0.1629, Accuracy: 1.0000
# Epoch 5, Loss: 0.1599, Accuracy: 1.0000
# Epoch 6, Loss: 0.1487, Accuracy: 0.9000
# Epoch 7, Loss: 0.1399, Accuracy: 1.0000
# Epoch 8, Loss: 0.1317, Accuracy: 1.0000
# Epoch 9, Loss: 0.1268, Accuracy: 1.0000
# Epoch 10, Loss: 0.1242, Accuracy: 1.0000
# Epoch 11, Loss: 0.1215, Accuracy: 1.0000
# Epoch 12, Loss: 0.1129, Accuracy: 1.0000
# Epoch 13, Loss: 0.1144, Accuracy: 1.0000
# Epoch 14, Loss: 0.1082, Accuracy: 1.0000
# Epoch 15, Loss: 0.1042, Accuracy: 1.0000
# Epoch 16, Loss: 0.0994, Accuracy: 1.0000
# Epoch 17, Loss: 0.1004, Accuracy: 1.0000
# Epoch 18, Loss: 0.0981, Accuracy: 1.0000
# Epoch 19, Loss: 0.0910, Accuracy: 1.0000
# Epoch 20, Loss: 0.0840, Accuracy: 1.0000
# Epoch 21, Loss: 0.0888, Accuracy: 1.0000
# Epoch 22, Loss: 0.0922, Accuracy: 1.0000
# Epoch 23, Loss: 0.0945, Accuracy: 1.0000
# Epoch 24, Loss: 0.0834, Accuracy: 1.0000
# Epoch 25, Loss: 0.0786, Accuracy: 1.0000
# Epoch 26, Loss: 0.0826, Accuracy: 1.0000
# Epoch 27, Loss: 0.0758, Accuracy: 1.0000
# Epoch 28, Loss: 0.0826, Accuracy: 1.0000
# Epoch 29, Loss: 0.0748, Accuracy: 1.0000
# Epoch 30, Loss: 0.0744, Accuracy: 1.0000
# Epoch 31, Loss: 0.0740, Accuracy: 1.0000
# Epoch 32, Loss: 0.0710, Accuracy: 1.0000
# Epoch 33, Loss: 0.0778, Accuracy: 1.0000
# Epoch 34, Loss: 0.0699, Accuracy: 1.0000
# Epoch 35, Loss: 0.0730, Accuracy: 1.0000
# Epoch 36, Loss: 0.0682, Accuracy: 1.0000
# Epoch 37, Loss: 0.0685, Accuracy: 1.0000
# Epoch 38, Loss: 0.0704, Accuracy: 1.0000
# Epoch 39, Loss: 0.0705, Accuracy: 0.9000
# Epoch 40, Loss: 0.0658, Accuracy: 1.0000
# Epoch 41, Loss: 0.0637, Accuracy: 0.9000
# Epoch 42, Loss: 0.0690, Accuracy: 1.0000
# Epoch 43, Loss: 0.0624, Accuracy: 1.0000
# Epoch 44, Loss: 0.0619, Accuracy: 1.0000
# Epoch 45, Loss: 0.0589, Accuracy: 1.0000
# Epoch 46, Loss: 0.0599, Accuracy: 1.0000
# Epoch 47, Loss: 0.0608, Accuracy: 1.0000
# Epoch 48, Loss: 0.0581, Accuracy: 1.0000
# Epoch 49, Loss: 0.0571, Accuracy: 0.9000
# Epoch 50, Loss: 0.0625, Accuracy: 1.0000
# Final Test Accuracy: 0.9626
# Execution Time: 708.29 seconds
# Training with Activation: tanh, Hidden Layer Size: 256
# Epoch 1, Loss: 1.0508, Accuracy: 0.8000
# Epoch 2, Loss: 0.6028, Accuracy: 1.0000
# Epoch 3, Loss: 0.5148, Accuracy: 1.0000
# Epoch 4, Loss: 0.5111, Accuracy: 0.8000
# Epoch 5, Loss: 0.4774, Accuracy: 1.0000
# Epoch 6, Loss: 0.4682, Accuracy: 1.0000
# Epoch 7, Loss: 0.4297, Accuracy: 1.0000
# Epoch 8, Loss: 0.4423, Accuracy: 1.0000
# Epoch 9, Loss: 0.4147, Accuracy: 1.0000
# Epoch 10, Loss: 0.4217, Accuracy: 1.0000
# Epoch 11, Loss: 0.4122, Accuracy: 1.0000
# Epoch 12, Loss: 0.3989, Accuracy: 1.0000
# Epoch 13, Loss: 0.3887, Accuracy: 0.9000
# Epoch 14, Loss: 0.3919, Accuracy: 0.9000
# Epoch 15, Loss: 0.3956, Accuracy: 1.0000
# Epoch 16, Loss: 0.3968, Accuracy: 1.0000
# Epoch 17, Loss: 0.3818, Accuracy: 1.0000
# Epoch 18, Loss: 0.3741, Accuracy: 1.0000
# Epoch 19, Loss: 0.3756, Accuracy: 1.0000
# Epoch 20, Loss: 0.3685, Accuracy: 0.9000
# Epoch 21, Loss: 0.3661, Accuracy: 0.9000
# Epoch 22, Loss: 0.3557, Accuracy: 1.0000
# Epoch 23, Loss: 0.3647, Accuracy: 1.0000
# Epoch 24, Loss: 0.3315, Accuracy: 1.0000
# Epoch 25, Loss: 0.3612, Accuracy: 1.0000
# Epoch 26, Loss: 0.3399, Accuracy: 1.0000
# Epoch 27, Loss: 0.3357, Accuracy: 1.0000
# Epoch 28, Loss: 0.3323, Accuracy: 1.0000
# Epoch 29, Loss: 0.3357, Accuracy: 1.0000
# Epoch 30, Loss: 0.3375, Accuracy: 1.0000
# Epoch 31, Loss: 0.3342, Accuracy: 1.0000
# Epoch 32, Loss: 0.3337, Accuracy: 1.0000
# Epoch 33, Loss: 0.3371, Accuracy: 1.0000
# Epoch 34, Loss: 0.3418, Accuracy: 1.0000
# Epoch 35, Loss: 0.3272, Accuracy: 1.0000
# Epoch 36, Loss: 0.3245, Accuracy: 1.0000
# Epoch 37, Loss: 0.3192, Accuracy: 1.0000
# Epoch 38, Loss: 0.3109, Accuracy: 1.0000
# Epoch 39, Loss: 0.3128, Accuracy: 1.0000
# Epoch 40, Loss: 0.3092, Accuracy: 1.0000
# Epoch 41, Loss: 0.3063, Accuracy: 1.0000
# Epoch 42, Loss: 0.3073, Accuracy: 1.0000
# Epoch 43, Loss: 0.3060, Accuracy: 1.0000
# Epoch 44, Loss: 0.3095, Accuracy: 1.0000
# Epoch 45, Loss: 0.3101, Accuracy: 1.0000
# Epoch 46, Loss: 0.3017, Accuracy: 1.0000
# Epoch 47, Loss: 0.3081, Accuracy: 1.0000
# Epoch 48, Loss: 0.2945, Accuracy: 1.0000
# Epoch 49, Loss: 0.2854, Accuracy: 1.0000
# Epoch 50, Loss: 0.2848, Accuracy: 1.0000
# Final Test Accuracy: 0.9601
# Execution Time: 969.41 seconds
# Training with Activation: tanh, Hidden Layer Size: 128
# Epoch 1, Loss: 0.7235, Accuracy: 0.9000
# Epoch 2, Loss: 0.3890, Accuracy: 1.0000
# Epoch 3, Loss: 0.3467, Accuracy: 1.0000
# Epoch 4, Loss: 0.3111, Accuracy: 1.0000
# Epoch 5, Loss: 0.2938, Accuracy: 1.0000
# Epoch 6, Loss: 0.2712, Accuracy: 1.0000
# Epoch 7, Loss: 0.2635, Accuracy: 1.0000
# Epoch 8, Loss: 0.2594, Accuracy: 1.0000
# Epoch 9, Loss: 0.2551, Accuracy: 1.0000
# Epoch 10, Loss: 0.2471, Accuracy: 1.0000
# Epoch 11, Loss: 0.2382, Accuracy: 1.0000
# Epoch 12, Loss: 0.2310, Accuracy: 1.0000
# Epoch 13, Loss: 0.2312, Accuracy: 1.0000
# Epoch 14, Loss: 0.2314, Accuracy: 1.0000
# Epoch 15, Loss: 0.2338, Accuracy: 1.0000
# Epoch 16, Loss: 0.2275, Accuracy: 1.0000
# Epoch 17, Loss: 0.2292, Accuracy: 1.0000
# Epoch 18, Loss: 0.2174, Accuracy: 0.9000
# Epoch 19, Loss: 0.2111, Accuracy: 1.0000
# Epoch 20, Loss: 0.2089, Accuracy: 1.0000
# Epoch 21, Loss: 0.2260, Accuracy: 1.0000
# Epoch 22, Loss: 0.1984, Accuracy: 1.0000
# Epoch 23, Loss: 0.1949, Accuracy: 1.0000
# Epoch 24, Loss: 0.2052, Accuracy: 1.0000
# Epoch 25, Loss: 0.2045, Accuracy: 0.9000
# Epoch 26, Loss: 0.2026, Accuracy: 1.0000
# Epoch 27, Loss: 0.2001, Accuracy: 1.0000
# Epoch 28, Loss: 0.2041, Accuracy: 1.0000
# Epoch 29, Loss: 0.1987, Accuracy: 1.0000
# Epoch 30, Loss: 0.1926, Accuracy: 1.0000
# Epoch 31, Loss: 0.1896, Accuracy: 1.0000
# Epoch 32, Loss: 0.1846, Accuracy: 1.0000
# Epoch 33, Loss: 0.1979, Accuracy: 1.0000
# Epoch 34, Loss: 0.1949, Accuracy: 1.0000
# Epoch 35, Loss: 0.1928, Accuracy: 1.0000
# Epoch 36, Loss: 0.1904, Accuracy: 1.0000
# Epoch 37, Loss: 0.1835, Accuracy: 1.0000
# Epoch 38, Loss: 0.1871, Accuracy: 1.0000
# Epoch 39, Loss: 0.1756, Accuracy: 0.9000
# Epoch 40, Loss: 0.1772, Accuracy: 1.0000
# Epoch 41, Loss: 0.1872, Accuracy: 1.0000
# Epoch 42, Loss: 0.1844, Accuracy: 0.8000
# Epoch 43, Loss: 0.1846, Accuracy: 1.0000
# Epoch 44, Loss: 0.1885, Accuracy: 1.0000
# Epoch 45, Loss: 0.1900, Accuracy: 1.0000
# Epoch 46, Loss: 0.1763, Accuracy: 1.0000
# Epoch 47, Loss: 0.1831, Accuracy: 1.0000
# Epoch 48, Loss: 0.1810, Accuracy: 1.0000
# Epoch 49, Loss: 0.1712, Accuracy: 1.0000
# Epoch 50, Loss: 0.1726, Accuracy: 1.0000
# Final Test Accuracy: 0.9599
# Execution Time: 776.93 seconds
# Training with Activation: tanh, Hidden Layer Size: 64
# Epoch 1, Loss: 0.6014, Accuracy: 0.9000
# Epoch 2, Loss: 0.3153, Accuracy: 1.0000
# Epoch 3, Loss: 0.2846, Accuracy: 0.9000
# Epoch 4, Loss: 0.2612, Accuracy: 0.9000
# Epoch 5, Loss: 0.2515, Accuracy: 1.0000
# Epoch 6, Loss: 0.2283, Accuracy: 1.0000
# Epoch 7, Loss: 0.2128, Accuracy: 1.0000
# Epoch 8, Loss: 0.2132, Accuracy: 1.0000
# Epoch 9, Loss: 0.1992, Accuracy: 1.0000
# Epoch 10, Loss: 0.2001, Accuracy: 1.0000
# Epoch 11, Loss: 0.1934, Accuracy: 1.0000
# Epoch 12, Loss: 0.1850, Accuracy: 1.0000
# Epoch 13, Loss: 0.1878, Accuracy: 1.0000
# Epoch 14, Loss: 0.1799, Accuracy: 0.9000
# Epoch 15, Loss: 0.1802, Accuracy: 1.0000
# Epoch 16, Loss: 0.1811, Accuracy: 0.9000
# Epoch 17, Loss: 0.1699, Accuracy: 1.0000
# Epoch 18, Loss: 0.1681, Accuracy: 1.0000
# Epoch 19, Loss: 0.1662, Accuracy: 1.0000
# Epoch 20, Loss: 0.1627, Accuracy: 0.8000
# Epoch 21, Loss: 0.1615, Accuracy: 1.0000
# Epoch 22, Loss: 0.1573, Accuracy: 1.0000
# Epoch 23, Loss: 0.1562, Accuracy: 1.0000
# Epoch 24, Loss: 0.1578, Accuracy: 0.9000
# Epoch 25, Loss: 0.1536, Accuracy: 1.0000
# Epoch 26, Loss: 0.1509, Accuracy: 1.0000
# Epoch 27, Loss: 0.1486, Accuracy: 1.0000
# Epoch 28, Loss: 0.1412, Accuracy: 0.9000
# Epoch 29, Loss: 0.1475, Accuracy: 1.0000
# Epoch 30, Loss: 0.1434, Accuracy: 0.9000
# Epoch 31, Loss: 0.1502, Accuracy: 1.0000
# Epoch 32, Loss: 0.1419, Accuracy: 1.0000
# Epoch 33, Loss: 0.1470, Accuracy: 1.0000
# Epoch 34, Loss: 0.1381, Accuracy: 1.0000
# Epoch 35, Loss: 0.1370, Accuracy: 1.0000
# Epoch 36, Loss: 0.1382, Accuracy: 1.0000
# Epoch 37, Loss: 0.1365, Accuracy: 1.0000
# Epoch 38, Loss: 0.1378, Accuracy: 1.0000
# Epoch 39, Loss: 0.1311, Accuracy: 1.0000
# Epoch 40, Loss: 0.1363, Accuracy: 1.0000
# Epoch 41, Loss: 0.1319, Accuracy: 0.9000
# Epoch 42, Loss: 0.1291, Accuracy: 1.0000
# Epoch 43, Loss: 0.1335, Accuracy: 1.0000
# Epoch 44, Loss: 0.1301, Accuracy: 1.0000
# Epoch 45, Loss: 0.1263, Accuracy: 1.0000
# Epoch 46, Loss: 0.1271, Accuracy: 1.0000
# Epoch 47, Loss: 0.1276, Accuracy: 1.0000
# Epoch 48, Loss: 0.1278, Accuracy: 1.0000
# Epoch 49, Loss: 0.1226, Accuracy: 1.0000
# Epoch 50, Loss: 0.1236, Accuracy: 1.0000
# Final Test Accuracy: 0.9585
# Execution Time: 730.16 seconds
# Hyperparameter Tuning Results:
# Activation: relu, Hidden Layer: 256, Test Accuracy: 0.9619, Time: 865.33s
# Activation: relu, Hidden Layer: 128, Test Accuracy: 0.9590, Time: 742.99s
# Activation: relu, Hidden Layer: 64, Test Accuracy: 0.9472, Time: 692.20s
# Activation: sigmoid, Hidden Layer: 256, Test Accuracy: 0.9685, Time: 902.55s
# Activation: sigmoid, Hidden Layer: 128, Test Accuracy: 0.9700, Time: 740.81s
# Activation: sigmoid, Hidden Layer: 64, Test Accuracy: 0.9626, Time: 708.29s
# Activation: tanh, Hidden Layer: 256, Test Accuracy: 0.9601, Time: 969.41s
# Activation: tanh, Hidden Layer: 128, Test Accuracy: 0.9599, Time: 776.93s
# Activation: tanh, Hidden Layer: 64, Test Accuracy: 0.9585, Time: 730.16s
